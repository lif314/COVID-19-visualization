# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - https://news.qq.com/zt2020/page/feiyan.htm
#
# ![image.png](attachment:image.png)

# %%
import requests
import json

url = "https://view.inews.qq.com/g2/getOnsInfo?name=disease_other"


res = requests.get(url)

res.encoding = 'utf-8'

data = json.loads(res.text)
# print(data)

# %%
type(data['data'])
# Out:
# str

# %%
data_all = json.loads(data['data'])
type(data_all)
# Out:
# dict

# %%
data_all.keys()
# Out:
# dict_keys(['cityStatis', 'chinaDayList', 'chinaDayAddList', 'provinceCompare', 'nowConfirmStatis', 'statisGradeCityDetail', 'dailyNewAddHistory', 'dailyHistory', 'wuhanDayList', 'articleList'])

# %%
print(data_all['cityStatis'])
print(data_all['provinceCompare'])
# Out:
# {'confirm': 348, 'zeroNowConfirm': 238, 'notZeroNowConfirm': 134}
# ...

# %%
shanghai_data = data_all['provinceCompare']['上海']
print(shanghai_data)
# Out:
# {'nowConfirm': -170, 'confirmAdd': 4, 'dead': 0, 'heal': 174, 'zero': 0}

# %%
print(len(data_all['chinaDayAddList']))
# Out:
# 60

# %% [markdown]
# ## 数据接口
#
# - 各国历史数据在：https://api.inews.qq.com/newsqa/v1/automation/foreign/daily/list?country=(意大利)
#
# - https://view.inews.qq.com/g2/getOnsInfo?name=disease_foreign
#
# - https://view.inews.qq.com/g2/getOnsInfo?name=disease_h5

# %%
import requests
import json

url = "https://view.inews.qq.com/g2/getOnsInfo?name=disease_h5"

res = requests.get(url)

# %%
# print(res.text)    # 错误原因：数据过长被nginx截断
# Out:
# {"ret":0,"data":"{\"lastUpdateTime\":\"2022-06-06 11:35:10\",\"chinaTotal\":{\"confirm\":2962016,\"heal\":294270,\"dead\":17551,\"suspect\":0,\"nowSevere\":57,\"importedCase\":18776,\"noInfect\":5265,\"showLocalConfirm\":1,\"showlocalinfeciton\":1,\"noInfectH5\":4751,\"localConfirmH5\":971,\"local_acc_confirm\":224341,\"localWzzAdd\":61,\"confirmAdd\":62164,\"nowLocalWzz\":4751,\"deadAdd\":0,\"mtime\":\"2022-06-06 09:16:53\",\"localConfirmAdd\":25,\"mediumRiskAreaNum\":30,\"highRiskAreaNum\":1,\"nowConfirm\":2650195,\"localConfirm\":1179,\"mRiskTime\":\"2022-06-06 15:31:02\"},\"chinaAdd\":{\"confirm\":62164,\"heal\":282,\"dead\":128,\"nowConfirm\":61754,\"suspect\":0,\"nowSevere\":-8,\"importedCase\":6,\"noInfect\":140,\"localConfirm\":-5,\"noInfectH5\":61,\"localConfirmH5\":25},\"isShowAdd\":true,\"showAddSwitch\":{\"all\":true,\"confirm\":true,\"suspect\":true,\"dead\":true,\"heal\":true,\"nowConfirm\":true,\"nowSevere\":true,\"importedCase\":true,\"noInfect\":true,\"localConfirm\"
# ...

# %%
print(res.headers)
print(res.encoding)
# Out:
# {'Date': 'Mon, 06 Jun 2022 08:55:19 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Server': 'openresty', 'Tracecode': '+R0b2GBc5ZoesQ==', 'X-Client-Ip': '9.56.36.153', 'X-Server-Ip': '58.250.137.40', 'Content-Encoding': 'gzip'}
# utf-8

# %%
data = json.loads(res.text)

# print(data['data'])
# print(data)

# %%
# print(data['data'])

# %%
d = data['data']
# print(d)
print(type(d))
print(len(d))
# Out:
# <class 'str'>
# 127563

# %%
data_all = json.loads(d)

print(type(data_all))  # +++, 接口数据有问题
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-22-a9889e2a8437> in <module>
# ----> 1 data_all = json.loads(d)
#       2
#       3 print(type(data_all))  # +++, 接口数据有问题
#
# D:\AppData\Anaconda\envs\covid\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# D:\AppData\Anaconda\envs\covid\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ...

# %%
url = "https://view.inews.qq.com/g2/getOnsInfo?name=disease_other"
headers = {
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Safari/537.36"
    }

r = requests.get(url, headers)

res = json.loads(r.text)

# %%
# print(res['data'])
data_all = json.loads(res['data'])
print(data_all.keys())
# Out:
# dict_keys(['cityStatis', 'chinaDayList', 'chinaDayAddList', 'provinceCompare', 'nowConfirmStatis', 'statisGradeCityDetail', 'dailyNewAddHistory', 'dailyHistory', 'wuhanDayList', 'articleList'])

# %%
print(data_all['chinaDayList'][0])
# Out:
# {'confirm': 495323, 'suspect': 23, 'dead': 14048, 'heal': 201985, 'nowConfirm': 279290, 'nowSevere': 77, 'importedCase': 17812, 'deadRate': '2.8', 'healRate': '40.8', 'date': '04.07', 'y': '2022', 'noInfect': 152693, 'localConfirm': 13353, 'noInfectH5': 151728, 'localConfirmH5': 13353, 'local_acc_confirm': 161692}

# %%
print(data_all['chinaDayAddList'][0])  # 全国每日新增数据
# Out:
# {'confirm': 2097, 'suspect': 4, 'dead': 111, 'heal': 2420, 'importedCase': 39, 'infect': 21784, 'localinfectionadd': 21711, 'localConfirmadd': 1284, 'deadRate': '5.3', 'healRate': '115.4', 'date': '04.06', 'y': '2022'}

# %%
print(data_all['statisGradeCityDetail'][0])  # 各省数据信息每日新增数据
# Out:
# {'province': '北京', 'city': '丰台', 'nowConfirm': 470, 'confirmAdd': 2, 'confirm': 707, 'dead': 0, 'heal': 237, 'grade': '点击查看详情', 'date': '06/06', 'mtime': '2022-06-06 08:16:47', 'sdate': '06/06', 'syear': 2022, 'wzz_add': '1'}

# %%
import time
def get_tencent_data():
    
    url = "https://view.inews.qq.com/g2/getOnsInfo?name=disease_other"
    headers = {
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Safari/537.36"
    }

    r = requests.get(url, headers)

    res = json.loads(r.text)

    data_all = json.loads(res["data"])

    # 获取中国每天疫情数据
    history = {}
    for day in data_all["chinaDayList"]:
        ds = day['y'] + "." + day['date']
        confirm = day["confirm"]
        suspect = day["suspect"]
        heal = day["heal"]
        dead = day["dead"]
        history[ds] = {"confirm": confirm, "suspect": suspect, "heal": heal, "dead": dead}
    # 全国每日新增数据
    for i in data_all["chinaDayAddList"]:
        ds = day['y'] + "." + day['date']
        confirm = i["confirm"]
        suspect = i["suspect"]
        heal = i["heal"]
        dead = i["dead"]
        history[ds].update({"confirm_add": confirm, "suspect_add": suspect, "heal_add": heal, "dead_add": dead})

    # 各省地区今天数据每日数据信息
    details = []
    for pro_infos in data_all['statisGradeCityDetail']:
        province = pro_infos["province"]
        city = pro_infos['city']
        confirm = pro_infos["confirm"]
        confirm_add = pro_infos["confirmAdd"]
        heal = pro_infos["heal"]
        dead = pro_infos["dead"]
        details.append([province, city, confirm, confirm_add, heal, dead])
    return history, details

# %%
history, details = get_tencent_data()

# %%
# print(history)

# %%
print(len(details))
# Out:
# 151
